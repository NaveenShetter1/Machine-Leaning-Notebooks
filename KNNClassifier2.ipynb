# %% [markdown]
# <a href="https://colab.research.google.com/github/NaveenShetter1/Machine-Leaning-Notebooks/blob/main/KNNClassifier2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Classified Data.csv',index_col=0)

# %%
df.head()
# Out:
#         WTT       PTI       EQW       SBI       LQE       QWG       FDJ  \
# 0  0.913917  1.162073  0.567946  0.755464  0.780862  0.352608  0.759697
# 1  0.635632  1.003722  0.535342  0.825645  0.924109  0.648450  0.675334
# 2  0.721360  1.201493  0.921990  0.855595  1.526629  0.720781  1.626351
# 3  1.234204  1.386726  0.653046  0.825624  1.142504  0.875128  1.409708
# 4  1.279491  0.949750  0.627280  0.668976  1.232537  0.703727  1.115596
#
#         PJF       HQE       NXJ  TARGET CLASS
# 0  0.643798  0.879422  1.231409             1
# 1  1.013546  0.621552  1.492702             0
# 2  1.154483  0.957877  1.285597             0
# 3  1.380003  1.522692  1.153093             1
# 4  0.646691  1.463812  1.419167             1

# %%
df.shape
# Out:
# (1000, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WTT           1000 non-null   float64
#  1   PTI           1000 non-null   float64
#  2   EQW           1000 non-null   float64
#  3   SBI           1000 non-null   float64
#  4   LQE           1000 non-null   float64
#  5   QWG           1000 non-null   float64
#  6   FDJ           1000 non-null   float64
#  7   PJF           1000 non-null   float64
#  8   HQE           1000 non-null   float64
#  9   NXJ           1000 non-null   float64
#  10  TARGET CLASS  1000 non-null   int64
# dtypes: float64(10), int64(1)
# memory usage: 93.8 KB

# %%
df.isnull().sum()
# Out:
# WTT             0
# PTI             0
# EQW             0
# SBI             0
# LQE             0
# QWG             0
# FDJ             0
# PJF             0
# HQE             0
# NXJ             0
# TARGET CLASS    0
# dtype: int64

# %%
df.describe()
# Out:
#                WTT          PTI          EQW          SBI          LQE  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.949682     1.114303     0.834127     0.682099     1.032336
# std       0.289635     0.257085     0.291554     0.229645     0.243413
# min       0.174412     0.441398     0.170924     0.045027     0.315307
# 25%       0.742358     0.942071     0.615451     0.515010     0.870855
# 50%       0.940475     1.118486     0.813264     0.676835     1.035824
# 75%       1.163295     1.307904     1.028340     0.834317     1.198270
# max       1.721779     1.833757     1.722725     1.634884     1.650050
#
#                QWG          FDJ          PJF          HQE          NXJ  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.943534     0.963422     1.071960     1.158251     1.362725
# std       0.256121     0.255118     0.288982     0.293738     0.204225
# min       0.262389     0.295228     0.299476     0.365157     0.639693
# 25%       0.761064     0.784407     0.866306     0.934340     1.222623
# 50%       0.941502     0.945333     1.065500     1.165556     1.375368
# 75%       1.123060     1.134852     1.283156     1.383173     1.504832
# max       1.666902     1.713342     1.785420     1.885690     1.893950
#
#        TARGET CLASS
# count    1000.00000
# mean        0.50000
# std         0.50025
# min         0.00000
# 25%         0.00000
# 50%         0.50000
# 75%         1.00000
# max         1.00000

# %%
x=df.drop('TARGET CLASS',axis=1)

# %%
x.head()
# Out:
#         WTT       PTI       EQW       SBI       LQE       QWG       FDJ  \
# 0  0.913917  1.162073  0.567946  0.755464  0.780862  0.352608  0.759697
# 1  0.635632  1.003722  0.535342  0.825645  0.924109  0.648450  0.675334
# 2  0.721360  1.201493  0.921990  0.855595  1.526629  0.720781  1.626351
# 3  1.234204  1.386726  0.653046  0.825624  1.142504  0.875128  1.409708
# 4  1.279491  0.949750  0.627280  0.668976  1.232537  0.703727  1.115596
#
#         PJF       HQE       NXJ
# 0  0.643798  0.879422  1.231409
# 1  1.013546  0.621552  1.492702
# 2  1.154483  0.957877  1.285597
# 3  1.380003  1.522692  1.153093
# 4  0.646691  1.463812  1.419167

# %%
y=df['TARGET CLASS']

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    1
# Name: TARGET CLASS, dtype: int64

# %%
x.shape
# Out:
# (1000, 10)

# %%
y.shape
# Out:
# (1000,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=47)

# %%
from scipy.stats import zscore

# %%
new_df=df.copy()

for i in new_df:
  print(i)
  print('==========')
  print('zscore    ', zscore(df[i]))
# Out:
# WTT
# ==========
# zscore     0     -0.123542
# 1     -1.084836
# 2     -0.788702
# 3      0.982841
# 4      1.139275
#          ...
# 995    0.211653
# 996   -1.292453
# 997    0.641777
# 998    0.467072
# 999   -0.387654
# Name: WTT, Length: 1000, dtype: float64
# PTI
# ==========
# zscore     0      0.185907
# 1     -0.430348
# 2      0.339318
# 3      1.060193
# 4     -0.640392
#          ...
# 995   -0.312490
# 996   -0.616901
# 997   -0.513083
# 998   -0.982786
# 999   -0.595894
# Name: PTI, Length: 1000, dtype: float64
# EQW
# ==========
# zscore     0     -0.913431
# 1     -1.025313
# 2      0.301511
# 3     -0.621399
# 4     -0.709819
#          ...
# 995    0.065163
# 996    0.369613
# 997   -0.179205
# 998   -1.465194
# 999   -1.431398
# Name: EQW, Length: 1000, dtype: float64
# SBI
# ==========
# zscore     0      0.319629
# 1      0.625388
# 2      0.755873
# 3      0.625299
# 4     -0.057175
#          ...
# 995   -0.259834
# 996    0.482648
# 997    1.022255
# 998   -0.071465
# 999    0.512722
# Name: SBI, Length: 1000, dtype: float64
# LQE
# ==========
# zscore     0     -1.033637
# 1     -0.444847
# 2      2.031693
# 3      0.452820
# 4      0.822886
#          ...
# 995    0.017567
# 996    1.569891
# 997   -0.539703
# 998    2.368666
# 999   -0.402552
# Name: LQE, Length: 1000, dtype: float64
# QWG
# ==========
# zscore     0     -2.308375
# 1     -1.152706
# 2     -0.870156
# 3     -0.267220
# 4     -0.936773
#          ...
# 995   -1.395721
# 996    1.273495
# 997   -0.229680
# 998    0.001269
# 999   -2.026512
# Name: QWG, Length: 1000, dtype: float64
# FDJ
# ==========
# zscore     0     -0.798951
# 1     -1.129797
# 2      2.599818
# 3      1.750208
# 4      0.596782
#          ...
# 995   -0.849486
# 996    0.362784
# 997   -2.261339
# 998   -0.422041
# 999   -0.726253
# Name: FDJ, Length: 1000, dtype: float64
# PJF
# ==========
# zscore     0     -1.482368
# 1     -0.202240
# 2      0.285707
# 3      1.066491
# 4     -1.472352
#          ...
# 995   -2.604264
# 996   -1.242110
# 997   -2.362494
# 998   -0.036777
# 999   -0.567789
# Name: PJF, Length: 1000, dtype: float64
# HQE
# ==========
# zscore     0     -0.949719
# 1     -1.828051
# 2     -0.682494
# 3      1.241325
# 4      1.040772
#          ...
# 995   -0.139347
# 996   -0.679746
# 997   -0.814261
# 998    0.406025
# 999    0.336997
# Name: HQE, Length: 1000, dtype: float64
# NXJ
# ==========
# zscore     0     -0.643314
# 1      0.636759
# 2     -0.377850
# 3     -1.026987
# 4      0.276510
#          ...
# 995   -0.069602
# 996    1.473448
# 997    0.111597
# 998   -0.855670
# 999    0.010350
# Name: NXJ, Length: 1000, dtype: float64
# TARGET CLASS
# ==========
# zscore     0      1.0
# 1     -1.0
# 2     -1.0
# 3      1.0
# 4      1.0
#       ...
# 995    1.0
# 996   -1.0
# 997    1.0
# 998    1.0
# 999    1.0
# Name: TARGET CLASS, Length: 1000, dtype: float64

# %%
def checkout(df):
  new_df=df.copy()
  for i in new_df:
    new_df[f'{i}--zscore']=zscore(new_df[i])

  return new_df

# %%
df=checkout(df)

# %%
df.head()
# Out:
#         WTT       PTI       EQW       SBI       LQE       QWG       FDJ  \
# 0  0.913917  1.162073  0.567946  0.755464  0.780862  0.352608  0.759697
# 1  0.635632  1.003722  0.535342  0.825645  0.924109  0.648450  0.675334
# 2  0.721360  1.201493  0.921990  0.855595  1.526629  0.720781  1.626351
# 3  1.234204  1.386726  0.653046  0.825624  1.142504  0.875128  1.409708
# 4  1.279491  0.949750  0.627280  0.668976  1.232537  0.703727  1.115596
#
#         PJF       HQE       NXJ  ...  PTI--zscore  EQW--zscore  SBI--zscore  \
# 0  0.643798  0.879422  1.231409  ...     0.185907    -0.913431     0.319629
# 1  1.013546  0.621552  1.492702  ...    -0.430348    -1.025313     0.625388
# 2  1.154483  0.957877  1.285597  ...     0.339318     0.301511     0.755873
# 3  1.380003  1.522692  1.153093  ...     1.060193    -0.621399     0.625299
# 4  0.646691  1.463812  1.419167  ...    -0.640392    -0.709819    -0.057175
#
#    LQE--zscore  QWG--zscore  FDJ--zscore  PJF--zscore  HQE--zscore  \
# 0    -1.033637    -2.308375    -0.798951    -1.482368    -0.949719
# 1    -0.444847    -1.152706    -1.129797    -0.202240    -1.828051
# 2     2.031693    -0.870156     2.599818     0.285707    -0.682494
# 3     0.452820    -0.267220     1.750208     1.066491     1.241325
# 4     0.822886    -0.936773     0.596782    -1.472352     1.040772
#
#    NXJ--zscore  TARGET CLASS--zscore
# 0    -0.643314                   1.0
# 1     0.636759                  -1.0
# 2    -0.377850                  -1.0
# 3    -1.026987                   1.0
# 4     0.276510                   1.0
#
# [5 rows x 22 columns]

# %%
df[(df['EQW--zscore']>3) | (df['EQW--zscore']<-3)]
# Out:
#           WTT       PTI       EQW       SBI       LQE       QWG       FDJ  \
# 702  1.109044  1.308035  1.722725  0.728863  1.239349  1.308794  0.770784
#
#           PJF       HQE       NXJ  ...  PTI--zscore  EQW--zscore  SBI--zscore  \
# 702  0.714099  0.917354  1.060216  ...     0.753951     3.049325     0.203737
#
#      LQE--zscore  QWG--zscore  FDJ--zscore  PJF--zscore  HQE--zscore  \
# 702     0.850885     1.426836    -0.755472    -1.238973    -0.820519
#
#      NXJ--zscore  TARGET CLASS--zscore
# 702    -1.481991                  -1.0
#
# [1 rows x 22 columns]

# %%
def checkout(df):
  new_df=df.copy()


  for i in new_df:
    if i[-6:]=="zscore":

      print(new_df[(new_df[i]>3) | (new_df[i]<-3)])

    else:
      print('yes')

      return None

# %%
checkout(df)
# Out:
# yes

# %%
a='EQW--zscore'
if a[-1:-6]=="zscore":
  print('yes')
else:
  print('no')
# Out:
# no

# %%
a[-6:]
# Out:
# 'zscore'

# %%
def checkout1(df):
  new_df=df.copy()

  count=0
  for i in new_df:
    cou=0
    if i[-6:]=="zscore":
      print('column name:       ',i)
      i=new_df[(new_df[i]>3) | (new_df[i]<-3)]
      print(i)
      count+=1
      cou+=1
  print('Total outliers :  ',count)
  return None

# %%
checkout1(df)
# Out:
# column name:        WTT--zscore
# Empty DataFrame
# Columns: [WTT, PTI, EQW, SBI, LQE, QWG, FDJ, PJF, HQE, NXJ, TARGET CLASS, WTT--zscore, PTI--zscore, EQW--zscore, SBI--zscore, LQE--zscore, QWG--zscore, FDJ--zscore, PJF--zscore, HQE--zscore, NXJ--zscore, TARGET CLASS--zscore]
# Index: []
#
# [0 rows x 22 columns]
# column name:        PTI--zscore
# Empty DataFrame
# Columns: [WTT, PTI, EQW, SBI, LQE, QWG, FDJ, PJF, HQE, NXJ, TARGET CLASS, WTT--zscore, PTI--zscore, EQW--zscore, SBI--zscore, LQE--zscore, QWG--zscore, FDJ--zscore, PJF--zscore, HQE--zscore, NXJ--zscore, TARGET CLASS--zscore]
# Index: []
#
# [0 rows x 22 columns]
# column name:        EQW--zscore
#           WTT       PTI       EQW       SBI       LQE       QWG       FDJ  \
# 702  1.109044  1.308035  1.722725  0.728863  1.239349  1.308794  0.770784
#
#           PJF       HQE       NXJ  ...  PTI--zscore  EQW--zscore  SBI--zscore  \
# 702  0.714099  0.917354  1.060216  ...     0.753951     3.049325     0.203737
#
#      LQE--zscore  QWG--zscore  FDJ--zscore  PJF--zscore  HQE--zscore  \
# 702     0.850885     1.426836    -0.755472    -1.238973    -0.820519
#
#      NXJ--zscore  TARGET CLASS--zscore
# 702    -1.481991                  -1.0
#
# [1 rows x 22 columns]
# column name:        SBI--zscore
#           WTT       PTI       EQW       SBI       LQE       QWG       FDJ  \
# 236  0.581659  1.059318  0.906429  1.634884  1.169260  1.380750  1.133712
# 379  1.025977  1.204174  0.740410  1.475274  1.152379  0.753080  0.622390
# 454  0.867456  0.837290  0.849896  1.402533  0.789160  1.425196  0.807210
# 593  0.879243  0.782903  0.429592  1.529917  0.944852  0.929111  1.500186
# 705  1.547884  0.809424  0.568956  1.409811  0.949120  0.734146  1.140667
# 990  0.876112  0.942414  1.060605  1.478041  0.818773  1.473635  1.306364
#
#           PJF       HQE       NXJ  ...  PTI--zscore  EQW--zscore  SBI--zscore  \
# 236  1.026216  0.842951  1.439077  ...    -0.213985     0.248115     4.151021
# 379  0.723727  1.441202  1.408169  ...     0.349752    -0.321602     3.455645
# 454  1.440814  0.619381  1.412058  ...    -1.078052     0.054114     3.138731
# 593  1.071709  1.131308  1.226876  ...    -1.289708    -1.388208     3.693707
# 705  0.907354  1.448846  1.081603  ...    -1.186499    -0.909966     3.170440
# 990  1.297386  0.522877  1.286394  ...    -0.668941     0.777185     3.467701
#
#      LQE--zscore  QWG--zscore  FDJ--zscore  PJF--zscore  HQE--zscore  \
# 236     0.562799     1.707925     0.667829    -0.158375    -1.073943
# 379     0.493410    -0.743983    -1.337429    -1.205641     0.963760
# 454    -0.999528     1.881546    -0.612619     1.277031    -1.835446
# 593    -0.359588    -0.056343     2.105038    -0.000871    -0.091770
# 705    -0.342045    -0.817947     0.695106    -0.569894     0.989796
# 990    -0.877809     2.070765     1.344923     0.780459    -2.164150
#
#      NXJ--zscore  TARGET CLASS--zscore
# 236     0.374051                  -1.0
# 379     0.222633                   1.0
# 454     0.241686                  -1.0
# 593    -0.665522                   1.0
# 705    -1.377217                   1.0
# 990    -0.373942                  -1.0
#
# [6 rows x 22 columns]
# column name:        LQE--zscore
# Empty DataFrame
# Columns: [WTT, PTI, EQW, SBI, LQE, QWG, FDJ, PJF, HQE, NXJ, TARGET CLASS, WTT--zscore, PTI--zscore, EQW--zscore, SBI--zscore, LQE--zscore, QWG--zscore, FDJ--zscore, PJF--zscore, HQE--zscore, NXJ--zscore, TARGET CLASS--zscore]
# Index: []
#
# [0 rows x 22 columns]
# column name:        QWG--zscore
# Empty DataFrame
# Columns: [WTT, PTI, EQW, SBI, LQE, QWG, FDJ, PJF, HQE, NXJ, TARGET CLASS, WTT--zscore, PTI--zscore, EQW--zscore, SBI--zscore, LQE--zscore, QWG--zscore, FDJ--zscore, PJF--zscore, HQE--zscore, NXJ--zscore, TARGET CLASS--zscore]
# Index: []
#
# [0 rows x 22 columns]
# column name:        FDJ--zscore
# Empty DataFrame
# Columns: [WTT, PTI, EQW, SBI, LQE, QWG, FDJ, PJF, HQE, NXJ, TARGET CLASS, WTT--zscore, PTI--zscore, EQW--zscore, SBI--zscore, LQE--zscore, QWG--zscore, FDJ--zscore, PJF--zscore, HQE--zscore, NXJ--zscore, TARGET CLASS--zscore]
# Index: []
#
# [0 rows x 22 columns]
# column name:        PJF--zscore
# Empty DataFrame
# Columns: [WTT, PTI, EQW, SBI, LQE, QWG, FDJ, PJF, HQE, NXJ, TARGET CLASS, WTT--zscore, PTI--zscore, EQW--zscore, SBI--zscore, LQE--zscore, QWG--zscore, FDJ--zscore, PJF--zscore, HQE--zscore, NXJ--zscore, TARGET CLASS--zscore]
# Index: []
#
# [0 rows x 22 columns]
# column name:        HQE--zscore
# Empty DataFrame
# Columns: [WTT, PTI, EQW, SBI, LQE, QWG, FDJ, PJF, HQE, NXJ, TARGET CLASS, WTT--zscore, PTI--zscore, EQW--zscore, SBI--zscore, LQE--zscore, QWG--zscore, FDJ--zscore, PJF--zscore, HQE--zscore, NXJ--zscore, TARGET CLASS--zscore]
# Index: []
#
# [0 rows x 22 columns]
# column name:        NXJ--zscore
#           WTT       PTI       EQW       SBI       LQE       QWG       FDJ  \
# 31   0.814005  0.596726  0.388931  0.626618  0.663819  0.984943  0.778532
# 294  0.819352  0.717993  0.683160  0.354237  1.086183  0.657049  0.753544
# 467  0.915663  0.966769  0.449077  0.595537  0.932468  1.199429  1.027023
# 572  1.160963  1.539060  0.776137  0.674328  1.191783  0.685757  1.252068
# 847  0.554928  1.444228  0.553958  0.998871  0.832654  1.195686  0.567277
#
#           PJF       HQE       NXJ  ...  PTI--zscore  EQW--zscore  SBI--zscore  \
# 31   0.840200  0.812728  0.741048  ...    -2.014257    -1.527742    -0.241718
# 294  0.803057  1.240532  0.703325  ...    -1.542320    -0.518059    -1.428406
# 467  0.409399  1.031367  0.639693  ...    -0.574157    -1.321342    -0.377127
# 572  0.497584  0.974205  0.725823  ...     1.653032    -0.199000    -0.033856
# 847  1.137975  1.067163  0.641499  ...     1.283973    -0.961433     1.380086
#
#      LQE--zscore  QWG--zscore  FDJ--zscore  PJF--zscore  HQE--zscore  \
# 31     -1.514718     0.161757    -0.725085    -0.802392    -1.176888
# 294     0.221326    -1.119115    -0.823082    -0.930985     0.280257
# 467    -0.410488     0.999618     0.249424    -2.293892    -0.432179
# 572     0.655375    -1.006974     1.131987    -1.988583    -0.626881
# 847    -0.820755     0.984997    -1.553568     0.228551    -0.310256
#
#      NXJ--zscore  TARGET CLASS--zscore
# 31     -3.045601                   1.0
# 294    -3.230405                   1.0
# 467    -3.542140                   1.0
# 572    -3.120186                  -1.0
# 847    -3.533290                  -1.0
#
# [5 rows x 22 columns]
# column name:        TARGET CLASS--zscore
# Empty DataFrame
# Columns: [WTT, PTI, EQW, SBI, LQE, QWG, FDJ, PJF, HQE, NXJ, TARGET CLASS, WTT--zscore, PTI--zscore, EQW--zscore, SBI--zscore, LQE--zscore, QWG--zscore, FDJ--zscore, PJF--zscore, HQE--zscore, NXJ--zscore, TARGET CLASS--zscore]
# Index: []
#
# [0 rows x 22 columns]
# Total outliers :   11

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

sc.fit_transform(x_train)
sc.transform(x_test)
# Out:
# array([[-0.48453084, -1.24535018, -1.993735  , ..., -0.73424164,
#          1.21401526, -2.01315859],
#        [ 0.77739169, -0.0479607 ,  0.59382622, ..., -2.17614343,
#          1.28883062, -0.60232262],
#        [ 0.21956249, -0.50610928, -0.68098911, ...,  0.16226264,
#          2.22171486, -0.09332683],
#        ...,
#        [-0.27060821,  1.87330542, -0.8472869 , ..., -1.41050032,
#         -1.41348135, -1.27435596],
#        [ 0.06199869, -0.77403819, -0.56839863, ..., -1.15259088,
#          1.31628949,  0.56371021],
#        [ 1.25453189,  0.34002186,  0.85493883, ...,  0.63112604,
#          0.77941875, -1.02409854]])

# %%
# for now i am ignoring the outliers

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred=knn.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, classification_report

# %%
print('accuracy score ', accuracy_score(y_test,y_pred))
# Out:
# accuracy score  0.95

# %%
print('classification_report:  ',classification_report(y_test,y_pred))
# Out:
# classification_report:                 precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       109
#            1       0.94      0.96      0.95        91
#
#     accuracy                           0.95       200
#    macro avg       0.95      0.95      0.95       200
# weighted avg       0.95      0.95      0.95       200

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[103,   6],
#        [  4,  87]])

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test,y_pred)).plot(cmap='Blues')
